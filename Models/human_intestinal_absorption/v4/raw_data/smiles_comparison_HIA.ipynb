# %%
import pandas as pd
from rdkit import Chem

# %%
df_cured = pd.read_csv('C:/Users/Enrique/Documents/ProtoADME para Enrique/ProtoADME_ABSORPTION/human_intestinal_absorption/v4/Output_files/human_intestinal_absorption-exp.txt', sep='\t')

#@title Sanitization in the database

#Create a list to include the sanitized SMILES
new_smiles = []
#Iterate on the list of SMILES
for smi in df_cured['SMILES']:
    try:
        #Sanitize if possible
        sanitized_smi = Chem.MolToSmiles(Chem.MolFromSmiles(smi))
    except:
        #Use None if not (None without "" because it is an empty value not a text)
        sanitized_smi = None

    #Append the value to the new_smiles list
    new_smiles.append(sanitized_smi)

#Include the new_smiles list as a new 'san_SMILES' column
df_cured['san_SMILES'] = new_smiles

df_cured = df_cured[df_cured['san_SMILES'].notna()] #You can use the notna() method inside the brackets

df_cured

df_cured = df_cured[['san_SMILES']]
df_cured.columns = ['SMILES']

df_cured
# Out:
#                                                  SMILES
# 0                 O=C1Nc2ccc(Cl)cc2C(c2ccccc2)=N[C@H]1O
# 1     CC(=O)OCC(=O)C1(O)CCC2C3CCC4=CC(=O)CCC4(C)C3C(...
# 2     C[C@@H](CCc1ccccc1)NC[C@@H](O)c1ccc(O)c(C(N)=O)c1
# 3     CN(C)C(=O)O[C@H]1N=C(c2ccccc2)c2cc(Cl)ccc2N(C)...
# 4          CCCC[C@H]1C(=O)N(c2ccccc2)N(c2ccc(O)cc2)C1=O
# ...                                                 ...
# 1234   Cc1ccc(S(=O)(=O)NC(=O)NN2C[C@H]3CCC[C@@H]3C2)cc1
# 1235                     CN(C)CCC=C1c2ccccc2CSc2ccccc21
# 1236                            CC[N+](C)(C)c1cccc(O)c1
# 1237               O=C(O)CN(CCN(CC(=O)O)CC(=O)O)CC(=O)O
# 1238               CC[C@@H](c1cccc(O)c1)[C@@H](C)CN(C)C
#
# [1239 rows x 1 columns]

# %%
df = pd.read_csv('raw_data_HIA.txt', sep='\t')

#@title Sanitization in the database

#Create a list to include the sanitized SMILES
new_smiles = []
#Iterate on the list of SMILES
for smi in df['SMILES']:
    try:
        #Sanitize if possible
        sanitized_smi = Chem.MolToSmiles(Chem.MolFromSmiles(smi))
    except:
        #Use None if not (None without "" because it is an empty value not a text)
        sanitized_smi = None

    #Append the value to the new_smiles list
    new_smiles.append(sanitized_smi)

#Include the new_smiles list as a new 'san_SMILES' column
df['san_SMILES'] = new_smiles

df = df[df['san_SMILES'].notna()] #You can use the notna() method inside the brackets
# Out:
# [09:07:36] SMILES Parse Error: syntax error while parsing: [C-]#N.C[C@@]([H])(CNC(=O)CC[C@@]1(C)C=2[N-][C@@]([H])([C@@]1([H])CC(N)=O)[C@@]5(C)N=C(C(C)=C4N=C(C=C3N=C(C=2C)[C@@]([H])(CCC(N)=O)C3(C)C)[C@@]([H])(CCC(N)=O)[C@@]4(C)CC(N)=O)[C@@]([H])(CCC(N)=O)[C@@]5(C)CC(N)=O)O[P](O)(=O)O[C@@]8([H])[C@@]([H])(CO)O[C@@]([H])(N7C=NC=6/C=C(/C)C(C)=CC=67)[C@@]8(O)[H].[Co+++]
# [09:07:36] SMILES Parse Error: Failed parsing SMILES '[C-]#N.C[C@@]([H])(CNC(=O)CC[C@@]1(C)C=2[N-][C@@]([H])([C@@]1([H])CC(N)=O)[C@@]5(C)N=C(C(C)=C4N=C(C=C3N=C(C=2C)[C@@]([H])(CCC(N)=O)C3(C)C)[C@@]([H])(CCC(N)=O)[C@@]4(C)CC(N)=O)[C@@]([H])(CCC(N)=O)[C@@]5(C)CC(N)=O)O[P](O)(=O)O[C@@]8([H])[C@@]([H])(CO)O[C@@]([H])(N7C=NC=6/C=C(/C)C(C)=CC=67)[C@@]8(O)[H].[Co+++]' for input: '[C-]#N.C[C@@]([H])(CNC(=O)CC[C@@]1(C)C=2[N-][C@@]([H])([C@@]1([H])CC(N)=O)[C@@]5(C)N=C(C(C)=C4N=C(C=C3N=C(C=2C)[C@@]([H])(CCC(N)=O)C3(C)C)[C@@]([H])(CCC(N)=O)[C@@]4(C)CC(N)=O)[C@@]([H])(CCC(N)=O)[C@@]5(C)CC(N)=O)O[P](O)(=O)O[C@@]8([H])[C@@]([H])(CO)O[C@@]([H])(N7C=NC=6/C=C(/C)C(C)=CC=67)[C@@]8(O)[H].[Co+++]'

# %%
df
df_final = df[['san_SMILES']]
df_final.columns = ['SMILES']
df_final
# Out:
#                                                  SMILES
# 0     NCC[C@H](O)C(=O)N[C@@H]1C[C@H](N)[C@@H](O[C@H]...
# 1     CC1(C)S[C@@H]2[C@H](NC(=O)[C@H](NC(=O)N3CCNC3=...
# 2     CC[C@@H]1CC[C@@H](N)[C@@H](O[C@H]2[C@H](O)[C@@...
# 3     NNC(=O)NNN1C(=O)c2cc(S(=O)(=O)O)cc3c(N)c(S(=O)...
# 4     C[C@H](O)[C@H]1C(=O)N2C(C(=O)O)=C(S[C@H]3CC[C@...
# ...                                                 ...
# 2041  CC(C)C([NH3+])C(=O)OCC(CO)OCn1cnc2c(=O)nc(N)[n...
# 2042                O=C1C(O)=C([O-])O[C@@H]1[C@@H](O)CO
# 2043                     O=C(CCCCCCC(=O)Nc1ccccc1)N[O-]
# 2044  COC(=O)[C@H]1[C@@H]2C[C@@H]3c4[nH]c5ccccc5c4CC...
# 2045      C[NH+](C)CCc1c[nH]c2ccc(C[C@H]3COC(=O)N3)cc12
#
# [2045 rows x 1 columns]

# %%
#@title Apply salt remover to the dataset
from rdkit.Chem.SaltRemover import SaltRemover

smi_no_salts = []
for smi in df['SMILES']:
    mol = Chem.MolFromSmiles(smi)
    remover = SaltRemover(defnData='[Na,Cl,K,O,OH,Fe,F,H,Al,Mg,Co,Ti,NH4,Mn,Si,Ca,Au,I,Hg,Mo,Zn,Br,Ag,Sr,Cu,Bi,S,Li,NH3,He,Y,Ar,Ba,La]')
    res = remover.StripMol(mol)
    new_smi = Chem.MolToSmiles(res)
    smi_no_salts.append(new_smi)

df['NO SALTS'] = smi_no_salts

df = df[df['NO SALTS']!= '']

#@title Inorganic removal in the dataset
allowed_atoms = ['H', 'N', 'C', 'O', 'P', 'S', 'Si', 'F', 'Cl', 'Br', 'I']

non_allowed_indx = []
#We reset the index to be sure that the index corresponds to the actual position of the SMILES in the list
df.reset_index(drop=True, inplace=True)

#Use enumerate to obtain the index in additon of the SMILES
for i, smi in enumerate(df['NO SALTS']):

    mol = Chem.MolFromSmiles(smi)
    for atom in mol.GetAtoms():
        atom_symbol = atom.GetSymbol()
        if atom_symbol not in allowed_atoms:
           non_allowed_indx.append(i)  # Append the index
           break

df.drop(non_allowed_indx,inplace=True)
df.reset_index(drop=True, inplace=True)

#@title Mixtures removal in the dataset
mixtures_indx = []

for i, smi in enumerate(df['NO SALTS']):
    if '.' in smi:
        mixtures_indx.append(i)

df.drop(mixtures_indx, inplace=True)
df.reset_index(drop=True, inplace=True)

#@title Removal of duplicates in the dataset
df.drop_duplicates(keep='first', inplace=False, ignore_index=False)

df_final = df[['NO SALTS']]
df_final.columns = ['SMILES']

# %%
df_final
# Out:
#                                                  SMILES
# 0     NCC[C@H](O)C(=O)N[C@@H]1C[C@H](N)[C@@H](O[C@H]...
# 1     CC1(C)S[C@@H]2[C@H](NC(=O)[C@H](NC(=O)N3CCNC3=...
# 2     CC[C@@H]1CC[C@@H](N)[C@@H](O[C@H]2[C@H](O)[C@@...
# 3     NNC(=O)NNN1C(=O)c2cc(S(=O)(=O)O)cc3c(N)c(S(=O)...
# 4     C[C@H](O)[C@H]1C(=O)N2C(C(=O)O)=C(S[C@H]3CC[C@...
# ...                                                 ...
# 2005  CC(C)C([NH3+])C(=O)OCC(CO)OCn1cnc2c(=O)nc(N)[n...
# 2006                O=C1C(O)=C([O-])O[C@@H]1[C@@H](O)CO
# 2007                     O=C(CCCCCCC(=O)Nc1ccccc1)N[O-]
# 2008  COC(=O)[C@H]1[C@@H]2C[C@@H]3c4[nH]c5ccccc5c4CC...
# 2009      C[NH+](C)CCc1c[nH]c2ccc(C[C@H]3COC(=O)N3)cc12
#
# [2010 rows x 1 columns]

# %%
def compare_compounds(df, txt_file_path):
    """
    Compara los compuestos en un DataFrame de pandas y un archivo TXT,
    e imprime los compuestos que son similares entre ambos.

    Parámetros:
    - df: DataFrame de pandas que contiene una columna con compuestos.
    - txt_file_path: Ruta al archivo TXT que contiene compuestos, uno por línea.
    """
    # Asegúrate de que el DataFrame tiene una columna 'compuesto' (o ajusta según sea necesario)
    compuestos_df = set(df['SMILES'])
    
    compuestos_txt = set(txt_file_path['SMILES'])
    # Leer el archivo TXT y obtener los compuestos
    #with open(txt_file_path, 'r') as file:
        #compuestos_txt = set(file.read().splitlines())
    
    # Encontrar la intersección de ambos conjuntos para identificar compuestos similares
    compuestos_similares = compuestos_df.intersection(compuestos_txt)
    
    if compuestos_similares:
        print("Compuestos similares encontrados:", len(compuestos_similares))
    else:
        print("No se encontraron compuestos similares.")

# Ejemplo de uso
# Supongamos que tienes un DataFrame 'df' y un archivo 'compuestos.txt'
df = df_final
df_cured = df_cured
compare_compounds(df, df_cured)
# Out:
# Compuestos similares encontrados: 984
